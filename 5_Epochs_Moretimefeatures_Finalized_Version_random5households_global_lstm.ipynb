# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('/content/drive/My Drive/uk_data_clean.csv')

# %%
pivoted = df.pivot(index='datetime', columns='id', values='target')

def dtarg(x):
  return(pd.to_datetime(x,format='%Y-%m-%d %H:%M:%S'))

pivoted.index = pivoted.index.map(dtarg)

np.random.seed(216)

testcols = np.random.choice(pivoted.columns, size=int((len(pivoted.columns)*.2)//1), replace=False, p=None)
traincols = [x for x in pivoted.columns if x not in testcols]

energy = pivoted[traincols]
energy_testing_set = pivoted[testcols]

# %%
energy_testing_set.columns
# Out:
# Index(['uk_MAC003375', 'uk_MAC004019', 'uk_MAC003901', 'uk_MAC002320',
#        'uk_MAC002547', 'uk_MAC001857', 'uk_MAC003796', 'uk_MAC003081',
#        'uk_MAC000714', 'uk_MAC003958',
#        ...
#        'uk_MAC000742', 'uk_MAC002753', 'uk_MAC003397', 'uk_MAC001665',
#        'uk_MAC004449', 'uk_MAC003082', 'uk_MAC005341', 'uk_MAC005162',
#        'uk_MAC001869', 'uk_MAC000769'],
#       dtype='object', name='id', length=183)

# %%
energy.columns
# Out:
# Index(['uk_MAC000010', 'uk_MAC000018', 'uk_MAC000019', 'uk_MAC000027',
#        'uk_MAC000034', 'uk_MAC000048', 'uk_MAC000049', 'uk_MAC000057',
#        'uk_MAC000075', 'uk_MAC000091',
#        ...
#        'uk_MAC005475', 'uk_MAC005480', 'uk_MAC005508', 'uk_MAC005525',
#        'uk_MAC005526', 'uk_MAC005527', 'uk_MAC005539', 'uk_MAC005540',
#        'uk_MAC005545', 'uk_MAC005549'],
#       dtype='object', name='id', length=736)

# %%
pivot = energy.copy()

# %%
pivot = pivot.iloc[:,:5]

# %%
pivot
# Out:
# id                   uk_MAC000010  uk_MAC000018  uk_MAC000019  uk_MAC000027  \
# datetime
# 2012-11-01 00:00:00         0.863         0.335         0.043         0.177
# 2012-11-01 00:30:00         0.287         0.500         0.069         0.185
# 2012-11-01 01:00:00         0.231         0.675         0.092         0.157
# 2012-11-01 01:30:00         0.177         0.554         0.088         0.179
# 2012-11-01 02:00:00         0.231         0.556         0.095         0.104
# ...                           ...           ...           ...           ...
# 2013-11-30 21:30:00         1.059         0.148         0.216         0.302
# 2013-11-30 22:00:00         0.833         0.139         0.192         0.258
# 2013-11-30 22:30:00         0.439         0.140         0.203         0.258
# 2013-11-30 23:00:00         0.488         0.142         0.167         0.231
# 2013-11-30 23:30:00         0.459         0.140         0.037         0.218
#
# id                   uk_MAC000034
# datetime
# 2012-11-01 00:00:00         0.584
# 2012-11-01 00:30:00         0.609
# 2012-11-01 01:00:00         0.164
# 2012-11-01 01:30:00         0.102
# 2012-11-01 02:00:00         0.129
# ...                           ...
# 2013-11-30 21:30:00         0.296
# 2013-11-30 22:00:00         0.264
# 2013-11-30 22:30:00         0.244
# 2013-11-30 23:00:00         0.553
# 2013-11-30 23:30:00         0.651
#
# [18960 rows x 5 columns]

# %%
tf = pd.DataFrame(index=pivot.index)
tf['hour'] = pivot.index.hour + pivot.index.minute / 60
tf['dow'] = pivot.index.dayofweek
tf['month'] = pivot.index.month

# Cyclical encodings
tf['hour_sin'] = np.sin(2 * np.pi * tf['hour'] / 24)
tf['hour_cos'] = np.cos(2 * np.pi * tf['hour'] / 24)
tf['dow_sin'] = np.sin(2 * np.pi * tf['dow'] / 7)
tf['dow_cos'] = np.cos(2 * np.pi * tf['dow'] / 7)
tf['month_sin'] = np.sin(2 * np.pi * tf['month'] / 12)
tf['month_cos'] = np.cos(2 * np.pi * tf['month'] / 12)

# 🆕 Additional time features
tf['is_weekend'] = (pivot.index.dayofweek >= 5).astype(int)
tf['is_month_start'] = pivot.index.is_month_start.astype(int)
tf['is_month_end'] = pivot.index.is_month_end.astype(int)
month = pivot.index.month
tf['season_winter'] = ((month == 12) | (month <= 2)).astype(int)
tf['season_spring'] = ((month >= 3) & (month <= 5)).astype(int)
tf['season_summer'] = ((month >= 6) & (month <= 8)).astype(int)
tf['season_autumn'] = ((month >= 9) & (month <= 11)).astype(int)

# Final time feature array
time_features = tf.values

# %%
#time_features_frame = pd.DataFrame(index=pivot.index)
#time_features_frame['hour'] = pivot.index.hour + pivot.index.minute / 60
#time_features_frame['dow'] = pivot.index.dayofweek
#time_features_frame['month'] = pivot.index.month

# Cyclical encodings
#time_features_frame['hour_sin'] = np.sin(2 * np.pi * time_features_frame['hour'] / 24)
#time_features_frame['hour_cos'] = np.cos(2 * np.pi * time_features_frame['hour'] / 24)
#time_features_frame['dow_sin'] = np.sin(2 * np.pi * time_features_frame['dow'] / 7)
#time_features_frame['dow_cos'] = np.cos(2 * np.pi * time_features_frame['dow'] / 7)
#time_features_frame['month_sin'] = np.sin(2 * np.pi * time_features_frame['month'] / 12)
#time_features_frame['month_cos'] = np.cos(2 * np.pi * time_features_frame['month'] / 12)

# 🆕 Additional time features
#time_features_frame['is_weekend'] = (pivot.index.dayofweek >= 5).astype(int)
#time_features_frame['is_month_start'] = pivot.index.is_month_start.astype(int)
#time_features_frame['is_month_end'] = pivot.index.is_month_end.astype(int)
#month = pivot.index.month
#time_features_frame['season_winter'] = ((month == 12) | (month <= 2)).astype(int)
#time_features_frame['season_spring'] = ((month >= 3) & (month <= 5)).astype(int)
#time_features_frame['season_summer'] = ((month >= 6) & (month <= 8)).astype(int)
#time_features_frame['season_autumn'] = ((month >= 9) & (month <= 11)).astype(int)

# Final time feature array
#time_features = time_features_frame.values

# %%
time_features
# Out:
# array([[ 0. ,  3. , 11. , ...,  0. ,  0. ,  1. ],
#        [ 0.5,  3. , 11. , ...,  0. ,  0. ,  1. ],
#        [ 1. ,  3. , 11. , ...,  0. ,  0. ,  1. ],
#        ...,
#        [22.5,  5. , 11. , ...,  0. ,  0. ,  1. ],
#        [23. ,  5. , 11. , ...,  0. ,  0. ,  1. ],
#        [23.5,  5. , 11. , ...,  0. ,  0. ,  1. ]])

# %%
time_features.shape
# Out:
# (18960, 16)

# %%
pivot.shape[0]
# Out:
# 18960

# %%
input_window = 7 * 48       # 336
forecast_horizon = 1 * 48   # 48

total_samples = pivot.shape[0] - input_window - forecast_horizon

# Create raw data splits before scaling
split1 = int(0.7 * total_samples)
split2 = int(0.85 * total_samples)

train_end = split1 + input_window + forecast_horizon
val_end = split2 + input_window + forecast_horizon

# Raw splits, unscaled
pivot_np = pivot.values
train_raw = pivot_np[:train_end]
val_raw   = pivot_np[train_end:val_end]
test_raw  = pivot_np[val_end:]

# %%
train_raw.shape
# Out:
# (13387, 5)

# %%
val_raw.shape
# Out:
# (2786, 5)

# %%
test_raw.shape
# Out:
# (2787, 5)

# %%
# Fit scaler on training data
scaler = MinMaxScaler()
scaler.fit(train_raw)

train_scaled = scaler.transform(train_raw)
val_scaled   = scaler.transform(val_raw)
test_scaled  = scaler.transform(test_raw)

# Time features must also be split accordingly
tf_train = time_features[:train_end]
tf_val   = time_features[train_end:val_end]
tf_test  = time_features[val_end:]

# %%
# Sequence creation function
def create_sequences(data, time_feats, input_window, forecast_horizon):
    X, y = [], []
    num_households = data.shape[1]
    for c in range(num_households):
        series = data[:, c]
        for i in range(len(series) - input_window - forecast_horizon):
            hist = series[i:i+input_window]
            tf_hist = time_feats[i:i+input_window, :]
            X.append(np.hstack([hist.reshape(-1, 1), tf_hist]))
            y.append(series[i+input_window:i+input_window+forecast_horizon].reshape(-1, 1))
    return np.array(X), np.array(y)

# Build sequences for each set
X_train, y_train = create_sequences(train_scaled, tf_train, input_window, forecast_horizon)
X_val, y_val     = create_sequences(val_scaled, tf_val, input_window, forecast_horizon)
X_test, y_test   = create_sequences(test_scaled, tf_test, input_window, forecast_horizon)

print("X_train shape:", X_train.shape)  # (samples, 336, 17)
print("y_train shape:", y_train.shape)  # (samples, 48, 1)
# Out:
# X_train shape: (65015, 336, 17)
# y_train shape: (65015, 48, 1)

# %%
print("X_val shape:", X_val.shape)  # (samples, 336, 17)
print("y_val shape:", y_val.shape)  # (samples, 48, 1)
print("X_test shape:", X_test.shape)  # (samples, 336, 17)
print("y_test shape:", y_test.shape)  # (samples, 48, 1)
# Out:
# X_val shape: (12010, 336, 17)
# y_val shape: (12010, 48, 1)
# X_test shape: (12015, 336, 17)
# y_test shape: (12015, 48, 1)

# %%
# LSTM model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, RepeatVector, TimeDistributed, Dense

model = Sequential([
    LSTM(64, input_shape=(input_window, X_train.shape[2])),
    RepeatVector(forecast_horizon),
    LSTM(64, return_sequences=True),
    TimeDistributed(Dense(1))
])

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        20,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector (RepeatVector)    │ (None, 48, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 48, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 48, 1)          │            65 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,081 (211.25 KB)
#  Trainable params: 54,081 (211.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=5,
    batch_size=8,
    verbose=1
)
# Out:
# Epoch 1/5
# 8127/8127 ━━━━━━━━━━━━━━━━━━━━ 153s 18ms/step - loss: 0.0131 - val_loss: 0.0043
# Epoch 2/5
# 8127/8127 ━━━━━━━━━━━━━━━━━━━━ 198s 18ms/step - loss: 0.0069 - val_loss: 0.0044
# Epoch 3/5
# 8127/8127 ━━━━━━━━━━━━━━━━━━━━ 213s 19ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 4/5
# 8127/8127 ━━━━━━━━━━━━━━━━━━━━ 191s 18ms/step - loss: 0.0059 - val_loss: 0.0040
# Epoch 5/5
# 8127/8127 ━━━━━━━━━━━━━━━━━━━━ 211s 19ms/step - loss: 0.0056 - val_loss: 0.0042

# %%
model.save('/content/drive/My Drive/5_epochs_17timefeatures_random5_lstm_energy_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Predict on scaled data
y_pred_scaled = model.predict(X_test)

# Setup
num_households = pivot.shape[1]  # 5 households
samples_per_household = len(X_test) // num_households

# Store all true/pred values unscaled
y_true_unscaled_all = []
y_pred_unscaled_all = []

for h in range(num_households):
    # Slice predictions and true labels for this household
    start = h * samples_per_household
    end = (h + 1) * samples_per_household

    y_pred_scaled_h = y_pred_scaled[start:end].reshape(-1, 1)  # (samples * 48, 1)
    y_true_scaled_h = y_test[start:end].reshape(-1, 1)

    # Get column-wise scaler params
    data_min = scaler.data_min_[h]
    data_max = scaler.data_max_[h]

    # Inverse scale
    y_pred_unscaled_h = y_pred_scaled_h * (data_max - data_min) + data_min
    y_true_unscaled_h = y_true_scaled_h * (data_max - data_min) + data_min

    y_pred_unscaled_all.append(y_pred_unscaled_h.flatten())
    y_true_unscaled_all.append(y_true_unscaled_h.flatten())

# Combine all households
y_pred_unscaled_flat = np.concatenate(y_pred_unscaled_all)
y_true_unscaled_flat = np.concatenate(y_true_unscaled_all)

# Accuracy metrics
mae_unscaled = mean_absolute_error(y_true_unscaled_flat, y_pred_unscaled_flat)
mse_unscaled = mean_squared_error(y_true_unscaled_flat, y_pred_unscaled_flat)
rmse_unscaled = np.sqrt(mean_squared_error(y_true_unscaled_flat, y_pred_unscaled_flat))

print(f"MAE (Unscaled):  {mae_unscaled:.4f}")
print(f"MSE (Unscaled): {mse_unscaled:.4f}")
print(f"RMSE (Unscaled): {rmse_unscaled:.4f}")
# Out:
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step
# MAE (Unscaled):  0.1356
# MSE (Unscaled): 0.0497
# RMSE (Unscaled): 0.2230

# %%
# to inspect which household performs better/worse

for h in range(num_households):
    mae_h = mean_absolute_error(y_true_unscaled_all[h], y_pred_unscaled_all[h])
    mse_h = mean_squared_error(y_true_unscaled_all[h], y_pred_unscaled_all[h])
    rmse_h = np.sqrt(mean_squared_error(y_true_unscaled_all[h], y_pred_unscaled_all[h]))
    print(f"Household {h+1}: MAE = {mae_h:.4f}, MSE = {mse_h:.4f}, RMSE = {rmse_h:.4f}")
# Out:
# Household 1: MAE = 0.2246, MSE = 0.1039, RMSE = 0.3224
# Household 2: MAE = 0.1110, MSE = 0.0274, RMSE = 0.1654
# Household 3: MAE = 0.0487, MSE = 0.0082, RMSE = 0.0906
# Household 4: MAE = 0.0735, MSE = 0.0136, RMSE = 0.1166
# Household 5: MAE = 0.2199, MSE = 0.0956, RMSE = 0.3092

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))

for h in range(num_households):
    idx = h * samples_per_household  # first test sample for this household
    y_pred_h = y_pred_unscaled_all[h].reshape(-1, 48)  # reshape back to (samples, 48)
    y_true_h = y_true_unscaled_all[h].reshape(-1, 48)

    y_pred_plot = y_pred_h[0]  # first forecasted day
    y_true_plot = y_true_h[0]

    plt.subplot(3, 2, h + 1)
    plt.plot(y_true_plot, linestyle='--', label='Actual')
    plt.plot(y_pred_plot, linewidth=2, label='Predicted')
    plt.title(f'Household {h+1} – Forecast vs Actual (Unscaled)')
    plt.xlabel("30-minute intervals")
    plt.ylabel("Energy (kWh)")
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Testing on UNSEEN households (183 that we separated in the beginning)

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Data: unseen households (183)
unseen_households = energy_testing_set.columns
num_unseen = len(unseen_households)

mae_list = []
mse_list = []
rmse_list = []
house_ids = []

for i, col in enumerate(unseen_households):
    series = energy_testing_set[col].values.reshape(-1, 1)

    # Skip short/incomplete series (shouldn't happen in our data)
    if len(series) < (input_window + forecast_horizon):
        continue

    # Scale this household independently
    scaler_h = MinMaxScaler()
    series_scaled = scaler_h.fit_transform(series)

    # Create time features (already built earlier)
    tf_unseen = time_features

    # Create sequences for this household
    X_h, y_h = create_sequences(series_scaled, tf_unseen, input_window, forecast_horizon)

    # Skip if not enough sequences
    if X_h.shape[0] == 0:
        continue

    # Predict
    y_h_pred = model.predict(X_h)

    # Inverse transform
    y_h_pred_unscaled = scaler_h.inverse_transform(y_h_pred.reshape(-1, 1)).flatten()
    y_h_true_unscaled = scaler_h.inverse_transform(y_h.reshape(-1, 1)).flatten()

    # Compute metrics
    mae = mean_absolute_error(y_h_true_unscaled, y_h_pred_unscaled)
    mse= mean_squared_error(y_h_true_unscaled, y_h_pred_unscaled)
    rmse = np.sqrt(mean_squared_error(y_h_true_unscaled, y_h_pred_unscaled))

    # Save results
    mae_list.append(mae)
    mse_list.append(mse)
    rmse_list.append(rmse)
    house_ids.append(col)

    print(f"Household {i+1}/{num_unseen} ({col}): MAE = {mae:.4f}, MSE = {mse:.4f}, RMSE = {rmse:.4f}")
# Out:
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step
# Household 1/183 (uk_MAC003375): MAE = 0.0921, MSE = 0.0180, RMSE = 0.1341
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step
# Household 2/183 (uk_MAC004019): MAE = 0.1123, MSE = 0.0281, RMSE = 0.1678
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step
# Household 3/183 (uk_MAC003901): MAE = 0.0990, MSE = 0.0221, RMSE = 0.1486
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step
# Household 4/183 (uk_MAC002320): MAE = 0.1070, MSE = 0.0317, RMSE = 0.1781
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step
# Household 5/183 (uk_MAC002547): MAE = 0.1000, MSE = 0.0201, RMSE = 0.1419
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 6/183 (uk_MAC001857): MAE = 0.1135, MSE = 0.0277, RMSE = 0.1665
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# Household 7/183 (uk_MAC003796): MAE = 0.1616, MSE = 0.0696, RMSE = 0.2638
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 8/183 (uk_MAC003081): MAE = 0.1099, MSE = 0.0325, RMSE = 0.1802
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 9/183 (uk_MAC000714): MAE = 0.0599, MSE = 0.0113, RMSE = 0.1061
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 10/183 (uk_MAC003958): MAE = 0.1413, MSE = 0.0512, RMSE = 0.2262
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# Household 11/183 (uk_MAC001909): MAE = 0.1186, MSE = 0.0363, RMSE = 0.1904
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 12/183 (uk_MAC000855): MAE = 0.2454, MSE = 0.1403, RMSE = 0.3745
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# Household 13/183 (uk_MAC001184): MAE = 0.0874, MSE = 0.0204, RMSE = 0.1429
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 14/183 (uk_MAC002168): MAE = 0.0984, MSE = 0.0160, RMSE = 0.1264
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 15/183 (uk_MAC005398): MAE = 0.2366, MSE = 0.2297, RMSE = 0.4792
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 16/183 (uk_MAC003237): MAE = 0.1585, MSE = 0.0752, RMSE = 0.2742
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 17/183 (uk_MAC005552): MAE = 0.1084, MSE = 0.0388, RMSE = 0.1971
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# Household 18/183 (uk_MAC003981): MAE = 0.1588, MSE = 0.0657, RMSE = 0.2564
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 19/183 (uk_MAC001645): MAE = 0.0915, MSE = 0.0290, RMSE = 0.1702
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# Household 20/183 (uk_MAC000281): MAE = 0.0876, MSE = 0.0184, RMSE = 0.1356
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 21/183 (uk_MAC000930): MAE = 0.0916, MSE = 0.0322, RMSE = 0.1795
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 22/183 (uk_MAC003535): MAE = 0.1356, MSE = 0.0459, RMSE = 0.2143
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 23/183 (uk_MAC004567): MAE = 0.1186, MSE = 0.0454, RMSE = 0.2131
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step
# Household 24/183 (uk_MAC004016): MAE = 0.4649, MSE = 0.5327, RMSE = 0.7298
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 25/183 (uk_MAC005382): MAE = 0.1604, MSE = 0.0918, RMSE = 0.3030
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 26/183 (uk_MAC004100): MAE = 0.0309, MSE = 0.0020, RMSE = 0.0444
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 27/183 (uk_MAC004319): MAE = 0.5280, MSE = 0.7599, RMSE = 0.8717
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 28/183 (uk_MAC005546): MAE = 0.0694, MSE = 0.0130, RMSE = 0.1141
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 29/183 (uk_MAC002300): MAE = 0.1097, MSE = 0.0375, RMSE = 0.1938
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 30/183 (uk_MAC002712): MAE = 0.1136, MSE = 0.0338, RMSE = 0.1838
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 31/183 (uk_MAC000462): MAE = 0.2087, MSE = 0.0995, RMSE = 0.3155
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 32/183 (uk_MAC000579): MAE = 0.0708, MSE = 0.0153, RMSE = 0.1239
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 33/183 (uk_MAC001060): MAE = 0.1795, MSE = 0.0652, RMSE = 0.2553
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 34/183 (uk_MAC004409): MAE = 0.3444, MSE = 0.2822, RMSE = 0.5312
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 35/183 (uk_MAC005220): MAE = 0.4060, MSE = 0.3707, RMSE = 0.6088
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 36/183 (uk_MAC004974): MAE = 0.0638, MSE = 0.0118, RMSE = 0.1085
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 37/183 (uk_MAC003059): MAE = 0.0384, MSE = 0.0029, RMSE = 0.0537
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 38/183 (uk_MAC005530): MAE = 0.0970, MSE = 0.0227, RMSE = 0.1506
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 39/183 (uk_MAC000147): MAE = 0.0730, MSE = 0.0162, RMSE = 0.1272
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 40/183 (uk_MAC000937): MAE = 0.0441, MSE = 0.0050, RMSE = 0.0709
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 41/183 (uk_MAC001972): MAE = 0.0775, MSE = 0.0179, RMSE = 0.1337
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 42/183 (uk_MAC000415): MAE = 0.2468, MSE = 0.1762, RMSE = 0.4198
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 43/183 (uk_MAC003512): MAE = 0.0915, MSE = 0.0233, RMSE = 0.1527
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 44/183 (uk_MAC000827): MAE = 0.1797, MSE = 0.1171, RMSE = 0.3422
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 45/183 (uk_MAC003250): MAE = 0.1097, MSE = 0.0282, RMSE = 0.1681
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 46/183 (uk_MAC003312): MAE = 0.0879, MSE = 0.0232, RMSE = 0.1523
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 47/183 (uk_MAC000331): MAE = 0.2473, MSE = 0.2057, RMSE = 0.4536
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 48/183 (uk_MAC002465): MAE = 0.0701, MSE = 0.0166, RMSE = 0.1288
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# Household 49/183 (uk_MAC000994): MAE = 0.1019, MSE = 0.0262, RMSE = 0.1620
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 50/183 (uk_MAC003150): MAE = 0.0889, MSE = 0.0190, RMSE = 0.1380
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 51/183 (uk_MAC004718): MAE = 0.2308, MSE = 0.1077, RMSE = 0.3282
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 52/183 (uk_MAC003658): MAE = 0.1384, MSE = 0.0622, RMSE = 0.2495
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 53/183 (uk_MAC000634): MAE = 0.0487, MSE = 0.0067, RMSE = 0.0817
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 54/183 (uk_MAC000676): MAE = 0.0678, MSE = 0.0098, RMSE = 0.0988
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 55/183 (uk_MAC001773): MAE = 0.0652, MSE = 0.0110, RMSE = 0.1048
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 56/183 (uk_MAC003860): MAE = 0.4137, MSE = 0.4135, RMSE = 0.6430
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 57/183 (uk_MAC000248): MAE = 0.1480, MSE = 0.0803, RMSE = 0.2834
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 58/183 (uk_MAC003417): MAE = 0.1607, MSE = 0.0666, RMSE = 0.2580
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 59/183 (uk_MAC001739): MAE = 0.6393, MSE = 0.7697, RMSE = 0.8773
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 60/183 (uk_MAC004419): MAE = 0.1267, MSE = 0.0466, RMSE = 0.2159
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 61/183 (uk_MAC001715): MAE = 0.1598, MSE = 0.0626, RMSE = 0.2502
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 62/183 (uk_MAC003815): MAE = 0.1031, MSE = 0.0275, RMSE = 0.1660
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 63/183 (uk_MAC004428): MAE = 0.2507, MSE = 0.2588, RMSE = 0.5087
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 64/183 (uk_MAC002433): MAE = 0.1417, MSE = 0.0584, RMSE = 0.2417
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 65/183 (uk_MAC002027): MAE = 0.1593, MSE = 0.0560, RMSE = 0.2367
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# Household 66/183 (uk_MAC005067): MAE = 0.1062, MSE = 0.0311, RMSE = 0.1763
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# Household 67/183 (uk_MAC004585): MAE = 0.2041, MSE = 0.0947, RMSE = 0.3078
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 68/183 (uk_MAC000700): MAE = 0.0595, MSE = 0.0140, RMSE = 0.1182
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 69/183 (uk_MAC002845): MAE = 0.0695, MSE = 0.0143, RMSE = 0.1195
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# Household 70/183 (uk_MAC003783): MAE = 0.1270, MSE = 0.0506, RMSE = 0.2249
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 71/183 (uk_MAC001472): MAE = 0.0554, MSE = 0.0119, RMSE = 0.1092
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# Household 72/183 (uk_MAC001176): MAE = 0.0364, MSE = 0.0030, RMSE = 0.0547
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 73/183 (uk_MAC003261): MAE = 0.1336, MSE = 0.0550, RMSE = 0.2345
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 74/183 (uk_MAC001447): MAE = 0.0898, MSE = 0.0249, RMSE = 0.1579
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 75/183 (uk_MAC003959): MAE = 0.1246, MSE = 0.0703, RMSE = 0.2651
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 76/183 (uk_MAC000590): MAE = 0.0630, MSE = 0.0093, RMSE = 0.0965
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# Household 77/183 (uk_MAC004463): MAE = 0.0987, MSE = 0.0330, RMSE = 0.1816
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 78/183 (uk_MAC003064): MAE = 0.1019, MSE = 0.0214, RMSE = 0.1464
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 79/183 (uk_MAC002979): MAE = 0.0604, MSE = 0.0084, RMSE = 0.0915
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 80/183 (uk_MAC004737): MAE = 0.0713, MSE = 0.0153, RMSE = 0.1238
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 81/183 (uk_MAC003330): MAE = 0.1636, MSE = 0.0632, RMSE = 0.2515
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 82/183 (uk_MAC002418): MAE = 0.0353, MSE = 0.0042, RMSE = 0.0649
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 83/183 (uk_MAC004122): MAE = 0.0480, MSE = 0.0079, RMSE = 0.0888
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 84/183 (uk_MAC003242): MAE = 0.0702, MSE = 0.0167, RMSE = 0.1294
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 85/183 (uk_MAC003940): MAE = 0.1306, MSE = 0.0460, RMSE = 0.2145
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 86/183 (uk_MAC003667): MAE = 0.5960, MSE = 0.5632, RMSE = 0.7505
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 87/183 (uk_MAC001750): MAE = 0.0777, MSE = 0.0185, RMSE = 0.1361
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 88/183 (uk_MAC002415): MAE = 0.1369, MSE = 0.0585, RMSE = 0.2419
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 89/183 (uk_MAC003355): MAE = 0.1821, MSE = 0.0903, RMSE = 0.3005
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 90/183 (uk_MAC003674): MAE = 0.1029, MSE = 0.0305, RMSE = 0.1747
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 91/183 (uk_MAC004015): MAE = 0.1313, MSE = 0.0403, RMSE = 0.2008
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 92/183 (uk_MAC002906): MAE = 0.0712, MSE = 0.0137, RMSE = 0.1171
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 93/183 (uk_MAC004929): MAE = 0.1680, MSE = 0.0575, RMSE = 0.2398
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 94/183 (uk_MAC004975): MAE = 0.0819, MSE = 0.0234, RMSE = 0.1529
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 95/183 (uk_MAC001485): MAE = 0.0832, MSE = 0.0257, RMSE = 0.1602
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 96/183 (uk_MAC005408): MAE = 0.0757, MSE = 0.0144, RMSE = 0.1200
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 97/183 (uk_MAC002969): MAE = 0.2355, MSE = 0.1727, RMSE = 0.4155
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 98/183 (uk_MAC002121): MAE = 0.1010, MSE = 0.0345, RMSE = 0.1856
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# Household 99/183 (uk_MAC001710): MAE = 0.1713, MSE = 0.0794, RMSE = 0.2818
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 100/183 (uk_MAC003896): MAE = 0.1666, MSE = 0.0718, RMSE = 0.2680
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 101/183 (uk_MAC000853): MAE = 0.0411, MSE = 0.0044, RMSE = 0.0662
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 102/183 (uk_MAC004860): MAE = 0.0325, MSE = 0.0027, RMSE = 0.0523
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 103/183 (uk_MAC004973): MAE = 0.0983, MSE = 0.0265, RMSE = 0.1627
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 104/183 (uk_MAC001097): MAE = 0.0936, MSE = 0.0294, RMSE = 0.1716
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 105/183 (uk_MAC005514): MAE = 0.0438, MSE = 0.0068, RMSE = 0.0823
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 106/183 (uk_MAC002346): MAE = 0.0996, MSE = 0.0284, RMSE = 0.1686
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 107/183 (uk_MAC002603): MAE = 0.1956, MSE = 0.0999, RMSE = 0.3160
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# Household 108/183 (uk_MAC005384): MAE = 0.0915, MSE = 0.0211, RMSE = 0.1451
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 109/183 (uk_MAC001367): MAE = 0.1243, MSE = 0.0364, RMSE = 0.1907
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# Household 110/183 (uk_MAC002619): MAE = 0.0371, MSE = 0.0031, RMSE = 0.0556
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 111/183 (uk_MAC004220): MAE = 0.0812, MSE = 0.0204, RMSE = 0.1427
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 112/183 (uk_MAC004085): MAE = 0.1551, MSE = 0.0616, RMSE = 0.2482
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 113/183 (uk_MAC002763): MAE = 0.2140, MSE = 0.1292, RMSE = 0.3594
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 114/183 (uk_MAC001651): MAE = 0.0894, MSE = 0.0247, RMSE = 0.1572
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 115/183 (uk_MAC004983): MAE = 0.3506, MSE = 0.4213, RMSE = 0.6490
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 116/183 (uk_MAC000260): MAE = 0.0982, MSE = 0.0281, RMSE = 0.1678
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 117/183 (uk_MAC002714): MAE = 0.1406, MSE = 0.0501, RMSE = 0.2239
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 118/183 (uk_MAC002066): MAE = 0.0658, MSE = 0.0129, RMSE = 0.1137
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 119/183 (uk_MAC001212): MAE = 0.0473, MSE = 0.0054, RMSE = 0.0735
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 120/183 (uk_MAC003695): MAE = 0.0318, MSE = 0.0019, RMSE = 0.0435
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 121/183 (uk_MAC001655): MAE = 0.0513, MSE = 0.0085, RMSE = 0.0920
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 122/183 (uk_MAC002429): MAE = 0.0510, MSE = 0.0056, RMSE = 0.0747
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 123/183 (uk_MAC001840): MAE = 0.0986, MSE = 0.0296, RMSE = 0.1721
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# Household 124/183 (uk_MAC004833): MAE = 0.0379, MSE = 0.0053, RMSE = 0.0728
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 125/183 (uk_MAC001480): MAE = 0.0577, MSE = 0.0073, RMSE = 0.0855
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 126/183 (uk_MAC004274): MAE = 0.1736, MSE = 0.1011, RMSE = 0.3179
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 127/183 (uk_MAC000754): MAE = 0.1179, MSE = 0.0479, RMSE = 0.2188
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 128/183 (uk_MAC000270): MAE = 0.0995, MSE = 0.0388, RMSE = 0.1970
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 129/183 (uk_MAC003080): MAE = 0.0703, MSE = 0.0120, RMSE = 0.1097
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 130/183 (uk_MAC005146): MAE = 0.0844, MSE = 0.0197, RMSE = 0.1405
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 131/183 (uk_MAC003431): MAE = 0.2745, MSE = 0.1903, RMSE = 0.4363
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 132/183 (uk_MAC000924): MAE = 0.0532, MSE = 0.0078, RMSE = 0.0882
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 133/183 (uk_MAC004951): MAE = 0.0485, MSE = 0.0068, RMSE = 0.0826
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 134/183 (uk_MAC005538): MAE = 0.0700, MSE = 0.0110, RMSE = 0.1048
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 135/183 (uk_MAC000455): MAE = 0.2757, MSE = 0.1486, RMSE = 0.3855
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 136/183 (uk_MAC004807): MAE = 0.0484, MSE = 0.0060, RMSE = 0.0773
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 137/183 (uk_MAC002292): MAE = 0.0332, MSE = 0.0024, RMSE = 0.0492
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 138/183 (uk_MAC003034): MAE = 0.1210, MSE = 0.0379, RMSE = 0.1948
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 139/183 (uk_MAC003124): MAE = 0.1671, MSE = 0.1103, RMSE = 0.3322
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 140/183 (uk_MAC001309): MAE = 0.0118, MSE = 0.0002, RMSE = 0.0154
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 141/183 (uk_MAC002301): MAE = 0.0436, MSE = 0.0041, RMSE = 0.0644
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 142/183 (uk_MAC001878): MAE = 0.1979, MSE = 0.0997, RMSE = 0.3158
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 143/183 (uk_MAC004930): MAE = 0.0550, MSE = 0.0066, RMSE = 0.0811
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 144/183 (uk_MAC005522): MAE = 0.2262, MSE = 0.1325, RMSE = 0.3641
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 145/183 (uk_MAC002949): MAE = 0.1904, MSE = 0.0886, RMSE = 0.2977
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 146/183 (uk_MAC004922): MAE = 0.2072, MSE = 0.1338, RMSE = 0.3658
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 147/183 (uk_MAC005380): MAE = 0.0980, MSE = 0.0227, RMSE = 0.1506
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 148/183 (uk_MAC002468): MAE = 0.0515, MSE = 0.0071, RMSE = 0.0844
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 149/183 (uk_MAC004206): MAE = 0.0511, MSE = 0.0063, RMSE = 0.0793
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 150/183 (uk_MAC004708): MAE = 0.1687, MSE = 0.0976, RMSE = 0.3124
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 151/183 (uk_MAC004934): MAE = 0.0792, MSE = 0.0166, RMSE = 0.1288
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 152/183 (uk_MAC001265): MAE = 0.1541, MSE = 0.0513, RMSE = 0.2264
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 153/183 (uk_MAC002737): MAE = 0.0645, MSE = 0.0135, RMSE = 0.1162
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 154/183 (uk_MAC004591): MAE = 0.0493, MSE = 0.0051, RMSE = 0.0713
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 155/183 (uk_MAC005273): MAE = 0.0404, MSE = 0.0030, RMSE = 0.0551
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 156/183 (uk_MAC004903): MAE = 0.2385, MSE = 0.1881, RMSE = 0.4337
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 157/183 (uk_MAC001214): MAE = 0.1384, MSE = 0.0617, RMSE = 0.2483
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 158/183 (uk_MAC005507): MAE = 0.1396, MSE = 0.0487, RMSE = 0.2206
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 159/183 (uk_MAC000322): MAE = 0.0603, MSE = 0.0110, RMSE = 0.1049
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 160/183 (uk_MAC000791): MAE = 0.1631, MSE = 0.0707, RMSE = 0.2660
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 161/183 (uk_MAC001605): MAE = 0.0986, MSE = 0.0363, RMSE = 0.1906
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 162/183 (uk_MAC004088): MAE = 0.0910, MSE = 0.0301, RMSE = 0.1736
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 163/183 (uk_MAC004436): MAE = 0.1192, MSE = 0.0640, RMSE = 0.2530
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 164/183 (uk_MAC001888): MAE = 0.0425, MSE = 0.0053, RMSE = 0.0729
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 165/183 (uk_MAC003536): MAE = 0.1147, MSE = 0.0355, RMSE = 0.1883
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 166/183 (uk_MAC000750): MAE = 0.1535, MSE = 0.0590, RMSE = 0.2429
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 167/183 (uk_MAC001187): MAE = 0.0982, MSE = 0.0199, RMSE = 0.1410
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# Household 168/183 (uk_MAC001202): MAE = 0.3429, MSE = 0.2463, RMSE = 0.4963
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 169/183 (uk_MAC002111): MAE = 0.1186, MSE = 0.0362, RMSE = 0.1902
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 170/183 (uk_MAC005085): MAE = 0.0542, MSE = 0.0071, RMSE = 0.0840
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Household 171/183 (uk_MAC000303): MAE = 0.0805, MSE = 0.0183, RMSE = 0.1353
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 172/183 (uk_MAC002709): MAE = 0.1954, MSE = 0.0793, RMSE = 0.2817
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 173/183 (uk_MAC004705): MAE = 0.1628, MSE = 0.0585, RMSE = 0.2418
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 174/183 (uk_MAC000742): MAE = 0.0819, MSE = 0.0149, RMSE = 0.1221
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 175/183 (uk_MAC002753): MAE = 0.0433, MSE = 0.0047, RMSE = 0.0687
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 176/183 (uk_MAC003397): MAE = 0.0852, MSE = 0.0219, RMSE = 0.1481
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 177/183 (uk_MAC001665): MAE = 0.2068, MSE = 0.0978, RMSE = 0.3127
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 178/183 (uk_MAC004449): MAE = 0.3214, MSE = 0.2285, RMSE = 0.4780
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 179/183 (uk_MAC003082): MAE = 0.0466, MSE = 0.0053, RMSE = 0.0727
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 180/183 (uk_MAC005341): MAE = 0.4768, MSE = 0.5941, RMSE = 0.7708
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 181/183 (uk_MAC005162): MAE = 0.1485, MSE = 0.0740, RMSE = 0.2720
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 182/183 (uk_MAC001869): MAE = 0.1439, MSE = 0.0496, RMSE = 0.2228
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Household 183/183 (uk_MAC000769): MAE = 0.0558, MSE = 0.0124, RMSE = 0.1115

# %%
# Overall metrics
print("\n Summary over all unseen households:")
print(f"Average MAE: {np.mean(mae_list):.4f}")
print(f"Average MSE: {np.mean(mse_list):.4f}")
print(f"Average RMSE: {np.mean(rmse_list):.4f}")
# Out:
#  Summary over all unseen households:
# Average MAE: 0.1311
# Average MSE: 0.0696
# Average RMSE: 0.2145

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.hist(mae_list, bins=30, alpha=0.7, label='MAE')
plt.hist(rmse_list, bins=30, alpha=0.7, label='RMSE')
plt.title("Error Distribution Across 183 Unseen Households")
plt.xlabel("Error (kWh)")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
results_df = pd.DataFrame({
    'household_id': house_ids,
    'mae': mae_list,
    'mse': mse_list,
    'rmse': rmse_list
})
results_df.to_csv('/content/drive/My Drive/5_epochs_new_unseen_household_accuracy.csv', index=False)

# %%
results_df
# Out:
#      household_id       mae       mse      rmse
# 0    uk_MAC003375  0.092113  0.017989  0.134122
# 1    uk_MAC004019  0.112258  0.028144  0.167763
# 2    uk_MAC003901  0.099029  0.022095  0.148644
# 3    uk_MAC002320  0.107022  0.031721  0.178103
# 4    uk_MAC002547  0.099961  0.020148  0.141942
# ..            ...       ...       ...       ...
# 178  uk_MAC003082  0.046647  0.005281  0.072672
# 179  uk_MAC005341  0.476780  0.594085  0.770769
# 180  uk_MAC005162  0.148485  0.073978  0.271988
# 181  uk_MAC001869  0.143897  0.049647  0.222816
# 182  uk_MAC000769  0.055823  0.012426  0.111473
#
# [183 rows x 4 columns]
